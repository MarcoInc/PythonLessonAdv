# %% [markdown]
# Data Scientist -> specialisti che lavorano ai Big Data
#
#
# Principali applicazioni dei BigData:
#
#     1. Contribuire miglioramento dei processi direzionali -> punti di scarsa produttivita
#
#     2. Offrono prodotti e servizi innovativi
#
#     3. Conoscenza altamente dettagliata dei singoli consumatori -> personalizzare i servizi da offrire
#
# Al al partire dal 2011 il termine BigData è stato cercato molte volte
#
# Ci sono 900 exabytes totali -> exa=10^18 byte
#
# Previsione per il 2025 -> 163 zettabye -> zetta=10^21
#
# In che modo i BigData migliorano il business?
#
#     1. Obiettivo preciso da raggiungere
#
#     2. Solo dati importanti
#
#     3. Favorire la collaborazione tra consulenti e dipedenti
#
#     4. Sfruttare il vantaggio dei software
#
#     5. Associare i paramentri ai numeri per allinearsi secondo alcune metriche
#
# Dalla Rete tutti vogliono le stesse cose
#
#     1. Informazioni e intrattenimento
#
#     2. Beni e servizi
#
# Una ottenuti i BigData che tutti noi produciamo, vanno trasmorati in SMART DATA ->  suggerimenti utili ed efficaci per orientare le vendite
#
# Software off-the-shelft per analizzare i dati:
#
#     1. Google Analytics per siti web
#
#     2. Facebook insight per le campagne social
#
# Marketing 3.0 oppure Marketing data-driven -> Approccio nel riacchiappare i clienti in base a pagine e mailing su misura

# %% [markdown]
# Per la regola delle 3V (Volume, Velocità, Varietà) i Big Data fanno un salto avanti grazie al Data Mining su:
#
#     *enormi quantita di VOLUME di dati <- V principale
#
#     *Dati da VARIETA' assai differenti
#
#     *Immagazinati ad una VELOCITA' sempre più alta
#
#
# DATI SUI BIG DATA
#
#     *Il GIRO DI AFFARI del 2017 -> 50 miliardi
#
#         (nel 2013 -> 10 miliardi)
#
#     * 18x di TRAFFICO DATI dal 2000 al 2018
#
#     *570 siti internet nascono ogni minuto
#
#     *4.4 milioni di posti di lavoro 2015 nel settore BigData
#
#     *La profilazione incide tra il 10% e 15% nei carelli e-coomerce
#
#     *2 milioni di POS installati
#
#     *62% dei negozianti britannici vogliono investire nell'analisi dei dati
#
#     * nel Oggi 18mila dottori in statistica negli USA
#         (nel 2012 9mila dottori)
#
#     * nel 2020 1/5 dei Big Data provengono dalla Cina
