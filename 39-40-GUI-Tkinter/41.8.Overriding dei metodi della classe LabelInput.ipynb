# %% [markdown]
# Visto che tutti gli oggetti (widget) LabelInput dovranno riempire l'intera cella della griglia in
# cui sono posti, si procede con l’overriding del metodo grid() (tra i metodi della classe LabelInput)
# con il seguente codice:
#
# ![image.png](attachment:image.png)
#
# In questo modo, si eviterà di aggiungere sticky=(tk.E + tk.W) a ciascuna chiamata
# LabelInput.grid().
#
#
# Tutti widget di input hanno, inoltre, tra i metodi, il metodo get() che restituisce il loro valore
# corrente. Per ridurre la ridondanza del codice in fase di utilizzo, si procederà con l’overriding anche
# del metodo get() che restituirà come valore del widget LabelInput il valore del widget di input o
# quello della variabile. L’overriding del metodo get() avviene con il seguente codice:
#
# ![image-2.png](attachment:image-2.png)
#
# Nel codice precedente, viene utilizzato un blocco try-except perché le variabili Tkinter
# lanciano un'eccezione dopo la chiamata a get() in alcune circostanze, ad esempio, se un campo
# numerico è vuoto.
#
# Nel caso di eccezione verrà restituita una stringa vuota. Anche i widget tk.Text
# dovranno essere gestiti in modo diverso poiché richiedono degli indici (nel nostro caso da 1.0 a
# tk.END) per recuperare tutto il testo contenuto nel widget.
